# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashas2001649/python/blob/main/Yashaswini_sk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_2015 = '/content/drive/MyDrive/Yashas/2015-building-energy-benchmarking (1).csv'
path_2016 = '/content/drive/MyDrive/Yashas/2016-building-energy-benchmarking.csv'

# %%
df_2015 = pd.read_csv(path_2015)
df_2016 = pd.read_csv(path_2016)

# %%
df_2015.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'TaxParcelIdentificationNumber', 'Location',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'OtherFuelUse(kBtu)',
# ...

# %%
print(df_2015.dtypes)
# Out:
# OSEBuildingID                                                      int64
# DataYear                                                           int64
# BuildingType                                                      object
# PrimaryPropertyType                                               object
# PropertyName                                                      object
# TaxParcelIdentificationNumber                                     object
# Location                                                          object
# CouncilDistrictCode                                                int64
# Neighborhood                                                      object
# YearBuilt                                                          int64
# NumberofBuildings                                                  int64
# NumberofFloors                                                   float64
# PropertyGFATotal                                                   int64
# ...

# %%
df_2016.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood',
#        'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
# ...

# %%
print(df_2016.dtypes)
# Out:
# OSEBuildingID                        int64
# DataYear                             int64
# BuildingType                        object
# PrimaryPropertyType                 object
# PropertyName                        object
# Address                             object
# City                                object
# State                               object
# ZipCode                            float64
# TaxParcelIdentificationNumber       object
# CouncilDistrictCode                  int64
# Neighborhood                        object
# Latitude                           float64
# Longitude                          float64
# YearBuilt                            int64
# NumberofBuildings                  float64
# NumberofFloors                       int64
# PropertyGFATotal                     int64
# PropertyGFAParking                   int64
# PropertyGFABuilding(s)               int64
# ListOfAllPropertyUseTypes           object
# LargestPropertyUseType              object
# ...

# %%
# %%capture
! pip install windows

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_2015.corr()
# Out:
#                                                     OSEBuildingID  ...  Zip Codes
# OSEBuildingID                                            1.000000  ...   0.051580
# DataYear                                                      NaN  ...        NaN
# CouncilDistrictCode                                     -0.092519  ...  -0.062987
# YearBuilt                                                0.134578  ...   0.037048
# NumberofBuildings                                       -0.000676  ...   0.026347
# NumberofFloors                                          -0.113519  ...  -0.129517
# PropertyGFATotal                                        -0.268611  ...  -0.071756
# PropertyGFAParking                                      -0.179414  ...  -0.070496
# PropertyGFABuilding(s)                                  -0.261334  ...  -0.063648
# LargestPropertyUseTypeGFA                               -0.252482  ...  -0.060120
# ...

# %%
df_2016.corr()
# Out:
#                                  OSEBuildingID  ...  GHGEmissionsIntensity
# OSEBuildingID                         1.000000  ...              -0.034985
# DataYear                                   NaN  ...                    NaN
# ZipCode                               0.084625  ...              -0.083394
# CouncilDistrictCode                  -0.089295  ...               0.003274
# Latitude                              0.092736  ...              -0.040727
# Longitude                             0.040473  ...               0.039365
# YearBuilt                             0.177302  ...              -0.146212
# NumberofBuildings                     0.025608  ...               0.027564
# NumberofFloors                       -0.103456  ...              -0.042445
# PropertyGFATotal                     -0.136508  ...               0.020105
# PropertyGFAParking                   -0.213901  ...              -0.043160
# ...

# %%
# sort the columns

df_2015 = df_2015.reindex(sorted(df_2015.columns), axis=1)
df_2016 = df_2016.reindex(sorted(df_2016.columns), axis=1)

# %%
print(set(df_2015.columns) - set(df_2016.columns))
# Out:
# {'Seattle Police Department Micro Community Policing Plan Areas', 'OtherFuelUse(kBtu)', 'Location', '2010 Census Tracts', 'Comment', 'Zip Codes', 'GHGEmissionsIntensity(kgCO2e/ft2)', 'GHGEmissions(MetricTonsCO2e)', 'City Council Districts', 'SPD Beats'}

# %%
# rename the columns in df_2016 which are different from df_2015 (set(2015)-set(2016))

df_2016.rename(columns={'Comments':'Comment','CouncilDistrictCode':'City Council Districts','ZipCode':'Zip Codes','GHGEmissionsIntensity':'GHGEmissionsIntensity(kgCO2e/ft2)'} , inplace=True)


df_2016.head()
# Out:
#            Address    BuildingType  ... YearsENERGYSTARCertified  Zip Codes
# 0    405 Olive way  NonResidential  ...                      NaN    98101.0
# 1  724 Pine street  NonResidential  ...                      NaN    98101.0
# 2  1900 5th Avenue  NonResidential  ...                      NaN    98101.0
# 3   620 STEWART ST  NonResidential  ...                      NaN    98101.0
# 4    401 LENORA ST  NonResidential  ...                      NaN    98121.0
#
# [5 rows x 46 columns]

# %%
print(len(df_2015.columns),len(df_2016.columns))
# Out:
# 47 46

# %%
#combine df_2015 and df_2016 (check merge)

df  = pd.concat([df_2015,df_2016],ignore_index=True)

df.columns
# Out:
# Index(['2010 Census Tracts', 'BuildingType', 'City Council Districts',
#        'Comment', 'ComplianceStatus', 'CouncilDistrictCode', 'DataYear',
#        'DefaultData', 'ENERGYSTARScore', 'Electricity(kBtu)',
#        'Electricity(kWh)', 'GHGEmissions(MetricTonsCO2e)',
#        'GHGEmissionsIntensity(kgCO2e/ft2)', 'LargestPropertyUseType',
#        'LargestPropertyUseTypeGFA', 'ListOfAllPropertyUseTypes', 'Location',
#        'NaturalGas(kBtu)', 'NaturalGas(therms)', 'Neighborhood',
#        'NumberofBuildings', 'NumberofFloors', 'OSEBuildingID',
#        'OtherFuelUse(kBtu)', 'Outlier', 'PrimaryPropertyType',
#        'PropertyGFABuilding(s)', 'PropertyGFAParking', 'PropertyGFATotal',
#        'PropertyName', 'SPD Beats',
#        'Seattle Police Department Micro Community Policing Plan Areas',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'SiteEUI(kBtu/sf)', 'SiteEUIWN(kBtu/sf)', 'SiteEnergyUse(kBtu)',
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Comment                                                          6703
# Outlier                                                          6600
# 2010 Census Tracts                                               6492
# YearsENERGYSTARCertified                                         6487
# ThirdLargestPropertyUseTypeGFA                                   5560
# ThirdLargestPropertyUseType                                      5560
# SecondLargestPropertyUseTypeGFA                                  3478
# SecondLargestPropertyUseType                                     3478
# GHGEmissions(MetricTonsCO2e)                                     3386
# OtherFuelUse(kBtu)                                               3386
# SPD Beats                                                        3378
# Seattle Police Department Micro Community Policing Plan Areas    3378
# CouncilDistrictCode                                              3376
# ...

# %%
df["Comment"].fillna(df["Comment"].mode(),inplace = True)

# %%
df.describe()
# Out:
#        2010 Census Tracts  ...  TotalGHGEmissions
# count          224.000000  ...        3367.000000
# mean           123.062500  ...         119.723971
# std              5.812128  ...         538.832227
# min            116.000000  ...          -0.800000
# 25%            117.000000  ...           9.495000
# 50%            123.000000  ...          33.920000
# 75%            125.500000  ...          93.940000
# max            135.000000  ...       16870.980000
#
# [8 rows x 35 columns]

# %%
df["Outlier"].fillna(df["Outlier"].mode(),inplace = True)

# %%
df["2010 Census Tracts"].fillna(df["2010 Census Tracts"].mode(),inplace = True)

# %%
df["YearsENERGYSTARCertified"].fillna(df["YearsENERGYSTARCertified"].mode(),inplace=True)

# %%
df["ThirdLargestPropertyUseTypeGFA"].fillna(df["ThirdLargestPropertyUseTypeGFA"].mean(),inplace=True)

# %%
df["ThirdLargestPropertyUseType"].fillna(df["ThirdLargestPropertyUseType"].mode(),inplace = True)

# %%
df["SecondLargestPropertyUseType"].fillna(df["SecondLargestPropertyUseType"].mode(),inplace = True)

# %%
df["SecondLargestPropertyUseType"].fillna(df["SecondLargestPropertyUseType"].mode(),inplace = True)

# %%
df["GHGEmissions(MetricTonsCO2e)"].fillna(df["GHGEmissions(MetricTonsCO2e)"].mean(),inplace = True)

# %%
df["OtherFuelUse(kBtu)"].fillna(df["OtherFuelUse(kBtu)"].mean(),inplace = True)

# %%
df["SPD Beats"].fillna(df["SPD Beats"].mean(),inplace = True)

# %%
df["Seattle Police Department Micro Community Policing Plan Areas"].fillna(df["Seattle Police Department Micro Community Policing Plan Areas"].mean(),inplace = True)

# %%
df["CouncilDistrictCode"].fillna(df["CouncilDistrictCode"].mean(),inplace = True)

# %%
df["Location"].fillna(df["Location"].mode(),inplace = True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Comment                                                          6690
# Outlier                                                          6599
# 2010 Census Tracts                                               6491
# YearsENERGYSTARCertified                                         6486
# ThirdLargestPropertyUseType                                      5559
# SecondLargestPropertyUseTypeGFA                                  3478
# SecondLargestPropertyUseType                                     3477
# Location                                                         3376
# TotalGHGEmissions                                                3349
# Address                                                          3340
# City                                                             3340
# State                                                            3340
# Latitude                                                         3340
# ...

# %%
#drop duplicates and filter out the data

df.drop_duplicates(inplace = True)

# %%
print(df.shape)
# Out:
# (6716, 53)

# %%
#divide the data into numerical and categorical type 

df_num = df.select_dtypes(np.number)
df_obj = df.select_dtypes('object')

df_num.columns
# Out:
# Index(['2010 Census Tracts', 'City Council Districts', 'CouncilDistrictCode',
#        'DataYear', 'ENERGYSTARScore', 'Electricity(kBtu)', 'Electricity(kWh)',
#        'GHGEmissions(MetricTonsCO2e)', 'GHGEmissionsIntensity(kgCO2e/ft2)',
#        'LargestPropertyUseTypeGFA', 'NaturalGas(kBtu)', 'NaturalGas(therms)',
#        'NumberofBuildings', 'NumberofFloors', 'OSEBuildingID',
#        'OtherFuelUse(kBtu)', 'PropertyGFABuilding(s)', 'PropertyGFAParking',
#        'PropertyGFATotal', 'SPD Beats',
#        'Seattle Police Department Micro Community Policing Plan Areas',
#        'SecondLargestPropertyUseTypeGFA', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)',
#        'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)', 'SteamUse(kBtu)',
#        'ThirdLargestPropertyUseTypeGFA', 'YearBuilt', 'Zip Codes', 'Latitude',
#        'Longitude', 'TotalGHGEmissions'],
#       dtype='object')

# %%
#missing values 

#If skewness is less than -1 or greater than 1, the distribution is highly skewed. If skewness is between -1 and -0.5 or between 0.5 and 1, the distribution is moderately skewed. If skewness is between -0.5 and 0.5, the distribution is approximately symmetric


df.skew(axis = 0, skipna = True) 

df_num.isna().sum()

for key in df_num.columns:
    if  -1 < df[key].skew(axis = 0, skipna = True) < 1 :
        df_num[key].fillna(df_num[key].mean() , inplace = True)
    else:
        df_num[key].fillna(df_num[key].median() , inplace = True)

df_num.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#        2010 Census Tracts  ...  TotalGHGEmissions
# count         6716.000000  ...        6716.000000
# mean           123.062222  ...          76.936970
# std              1.059168  ...         383.899003
# min            116.000000  ...          -0.800000
# 25%            123.062222  ...          33.730000
# 50%            123.062222  ...          33.920000
# 75%            123.062222  ...          34.032500
# max            135.000000  ...       16870.980000
#
# [8 rows x 35 columns]

# %%
#data visualization of numerical data 

df_num.corr()

corr = df_num.corr()
plt.figure(figsize=(8, 10))
df4 = sns.heatmap(corr , linewidths=.5 , annot_kws={"fontsize":10})

# %%
# normalizing 
#df = (df - df.mean())/(df.std()) 

df_num.columns
# Out:
# Index(['2010 Census Tracts', 'City Council Districts', 'CouncilDistrictCode',
#        'DataYear', 'ENERGYSTARScore', 'Electricity(kBtu)', 'Electricity(kWh)',
#        'GHGEmissions(MetricTonsCO2e)', 'GHGEmissionsIntensity(kgCO2e/ft2)',
#        'LargestPropertyUseTypeGFA', 'NaturalGas(kBtu)', 'NaturalGas(therms)',
#        'NumberofBuildings', 'NumberofFloors', 'OSEBuildingID',
#        'OtherFuelUse(kBtu)', 'PropertyGFABuilding(s)', 'PropertyGFAParking',
#        'PropertyGFATotal', 'SPD Beats',
#        'Seattle Police Department Micro Community Policing Plan Areas',
#        'SecondLargestPropertyUseTypeGFA', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)',
#        'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)', 'SteamUse(kBtu)',
#        'ThirdLargestPropertyUseTypeGFA', 'YearBuilt', 'Zip Codes', 'Latitude',
#        'Longitude', 'TotalGHGEmissions'],
#       dtype='object')

# %%
df_test=df[['BuildingType','LargestPropertyUseType','PropertyGFATotal']]
df_grp=df_test.groupby(['BuildingType','LargestPropertyUseType'],as_index=False).mean()
df_grp
# Out:
#           BuildingType  ... PropertyGFATotal
# 0               Campus  ...     5.795200e+04
# 1               Campus  ...     1.578559e+06
# 2               Campus  ...     5.198900e+04
# 3               Campus  ...     2.280000e+04
# 4               Campus  ...     4.550000e+04
# ..                 ...  ...              ...
# 94  Nonresidential COS  ...     4.417450e+04
# 95  Nonresidential COS  ...     2.555700e+04
# 96   Nonresidential WA  ...     6.807200e+04
# 97   SPS-District K-12  ...     9.017671e+04
# 98   SPS-District K-12  ...     1.853265e+05
#
# [99 rows x 3 columns]

# %%
df_num['2010 Census Tracts'].head()
# Out:
# 0    123.000000
# 1    123.062222
# 2    123.062222
# 3    123.062222
# 4    123.062222
# Name: 2010 Census Tracts, dtype: float64

# %%
fig = plt.figure() # create figure

ax0 = fig.add_subplot(1, 2, 1)
ax1 = fig.add_subplot(1, 2, 2)

df_num['GHGEmissions(MetricTonsCO2e)'].plot(kind='hist', color='blue', figsize=(20, 6), ax=ax0)
df_num['GHGEmissionsIntensity(kgCO2e/ft2)'].plot(kind='hist', color='blue', figsize=(20, 6), ax=ax1)

# %% [markdown]
# The above plot shows that skewness is more towards right.

# %%
fig = plt.figure() # create figure

ax0 = fig.add_subplot(1, 2, 1)
ax1 = fig.add_subplot(1, 2, 2)

df_num['Electricity(kBtu)'].plot(kind='hist', color='blue', figsize=(20, 6), ax=ax0)
df_num['Electricity(kWh)'].plot(kind='hist', color='blue', figsize=(20, 6), ax=ax1)

ax0.set_title('historgram form electricity in kBtu ')
ax1.set_title('historgram form electricity in kWh ')
# Out:
# Text(0.5, 1.0, 'historgram form electricity in kWh ')

# %% [markdown]
# The above plot shows that skewness is more towards right.

# %%
fig = plt.figure( figsize = (15,5)) # create figure

ax0 = fig.add_subplot(1, 2, 1)
ax1 = fig.add_subplot(1,2,2)


ax0.scatter(df_num.index , df_num['Electricity(kBtu)'])
ax1.scatter(df_num.index , df_num['Electricity(kWh)'])

# %%
fig = plt.figure() # create figure

ax0 = fig.add_subplot(1, 2, 1)
ax1 = fig.add_subplot(1, 2, 2)

df_num['SiteEnergyUse(kBtu)'].plot(kind='hist', color='blue', figsize=(10, 6), ax=ax0)
df_num['SiteEnergyUseWN(kBtu)'].plot(kind='hist', color='blue', figsize=(10, 6), ax=ax1)

plt.show()

# %% [markdown]
# The above plot shows that skewness is more towards right

# %%
df.plot(kind='bar', figsize=(15, 15))

plt.xlabel('Electricity(kBtu)') # add to x-label to the plot
plt.ylabel('Electricity(kWh)') # add y-label to the plot

plt.show()

# %%
# data visualization of categorical data   
       

df_obj.columns

df1 =  df_obj['PrimaryPropertyType']
plt.figure(figsize=(20,5))
ax = sns.countplot( df1)    
plt.xticks(rotation=90 , fontsize = 15)
plt.yticks(fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([   0.,  250.,  500.,  750., 1000., 1250., 1500., 1750., 2000.,
#         2250.]), <a list of 10 Text major ticklabel objects>)

# %%
df2 = df_obj['LargestPropertyUseType']
plt.figure(figsize=(20,5))
bx = sns.countplot(df2)
plt.xticks(rotation=90 , fontsize = 15)
plt.yticks(fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500.]),
#  <a list of 8 Text major ticklabel objects>)

# %%
 df3 = df_obj['ThirdLargestPropertyUseType'].value_counts()
df3.plot(kind='pie', figsize=(10, 10), shadow=True ,startangle=90, autopct='%1.1f%%', fontsize = 15)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.boxplot(x="BuildingType", y="SiteEUI(kBtu/sf)", data=df)
#annual amount of all energy consumed by the property on site

# %% [markdown]
# The above plot shows that median is present nearly at 100 range,first quartile is present nearly at 80 range,Third quartile is present nearly at 120 range,maximum nearly at 180 ,minimum nearly at 20 range,outliers is present above 200 range.

# %%
df
# Out:
#       2010 Census Tracts        BuildingType  ...  State TotalGHGEmissions
# 0                  123.0      NonResidential  ...    NaN               NaN
# 1                    NaN      NonResidential  ...    NaN               NaN
# 2                    NaN      NonResidential  ...    NaN               NaN
# 3                    NaN      NonResidential  ...    NaN               NaN
# 4                    NaN      NonResidential  ...    NaN               NaN
# ...                  ...                 ...  ...    ...               ...
# 6711                 NaN  Nonresidential COS  ...     WA             20.94
# 6712                 NaN  Nonresidential COS  ...     WA             32.17
# 6713                 NaN  Nonresidential COS  ...     WA            223.54
# 6714                 NaN  Nonresidential COS  ...     WA             22.11
# 6715                 NaN  Nonresidential COS  ...     WA             41.27
#
# [6716 rows x 53 columns]

# %% [markdown]
# ## Label encoder

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
df['BuildingType']= label_encoder.fit_transform(df['BuildingType']) 
  
df['BuildingType'].unique()
# Out:
# array([4, 5, 3, 7, 2, 0, 1, 6])

# %%
df_num.replace([np.inf, -np.inf], np.nan, inplace=True) 
  
# Dropping all the rows with nan values 
df_num.dropna(inplace=True) 
  
# Printing df 
df_num
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#       2010 Census Tracts  City Council Districts  ...   Longitude  TotalGHGEmissions
# 0             123.000000                4.255782  ... -122.334795              33.92
# 1             123.062222                4.255782  ... -122.334795              33.92
# ...

# %% [markdown]
# ## Building the model

# %%
X = df_num[[ 'ENERGYSTARScore','Electricity(kBtu)','NaturalGas(kBtu)', 'OtherFuelUse(kBtu)','PropertyGFATotal', 'SiteEnergyUseWN(kBtu)','SourceEUI(kBtu/sf)','SteamUse(kBtu)']]
X
# Out:
#       ENERGYSTARScore  Electricity(kBtu)  ...  SourceEUI(kBtu/sf)  SteamUse(kBtu)
# 0           65.000000       3.686160e+06  ...          173.500000       2023032.0
# 1           51.000000       3.905411e+06  ...          191.300000             0.0
# 2           18.000000       4.976244e+07  ...          242.700000      19660404.0
# 3            1.000000       2.769023e+06  ...          636.300000      23458518.0
# 4           67.000000       6.066245e+06  ...          228.800000             0.0
# ...               ...                ...  ...                 ...             ...
# 6711        46.000000       5.242709e+05  ...          161.699997             0.0
# 6712        67.906342       3.965461e+05  ...          114.199997             0.0
# 6713        67.906342       1.792159e+06  ...          744.799988             0.0
# 6714        67.906342       3.488702e+05  ...          105.300003             0.0
# ...

# %%
y = df_num['GHGEmissions(MetricTonsCO2e)']
y.astype(float)
# Out:
# 0        249.430000
# 1        263.510000
# 2       2061.480000
# 3       1936.340000
# 4        507.700000
#            ...
# 6711     110.094102
# 6712     110.094102
# 6713     110.094102
# 6714     110.094102
# 6715     110.094102
# Name: GHGEmissions(MetricTonsCO2e), Length: 6716, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %%
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lr.predict(X_test)

# %%
lr.score(X_train,y_train)
# Out:
# 0.36120630847424806

# %%
lr.score(X_test,y_test)
# Out:
# 0.4976408790015171

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4976408790015171
